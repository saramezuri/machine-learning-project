# %% [markdown]
# ## Using Stocknews API to grab financial data
# The script uses `requests` module to extract financial news headlines, and other important features such as Time and Date, News Outlet, Sector (Technology, Healthcare, Finance), Summary Text and Headline (used for sentimental analysis calculation), Tickers.
#
# The next part of this script is using the Headline and Summary text extracted from the API to calculate the sentimental score using Vader, check `https://github.com/cjhutto/vaderSentiment` for more information.

# %% [markdown]
# ### Import necessary libraries

# %%
import requests
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd
import os

# %% [markdown]
# I defined the API_KEY that you can all use to grab financial news info, more syntax on the documentation can be found here: `https://stocknewsapi.com/documentation`
#
# This part is fixed so we can define them here, for the date_range you can play around and choose only a specific day or a shorter time range

# %%
API_KEY = 'n44o8yuk9jdyg4lgw8rsueij4xmv5gznbpsw9rni'
date_range = '03152019-03152024'
sectors = ['technology', 'healthcare', 'financial']

# %% [markdown]
# ## Using only one Sector
#
# `base_url: https://stocknewsapi.com/api/v1/category?section=alltickers` - this is the location of where the financial data are
# - `section=alltickers` mean its for all available stocks (I did more filtering in the next line)
# `url = f'{base_url}&sector=technology&exchange=NYSE,NASDAQ&index=SP500&country=USA&type=article&date={date_range}&items=100&page=1&extra-fields=id&token={API_KEY}'`
# - `sector=technology`: this specifies the sector you want so you can manually change this or as you can see below, over a loop
# - `exchange=NYSE, NASDAQ`: these are the two main sources of S&P500 stocks
# - `index=SP500`: only limiting to SP 500 stocks
# - `country=USA`: limited to US
# - `type=article`: they also have videos, however I couldn't get proper sentiment scores so I sticked to articles
# - `date_range`: the variable above is fixed from March 15, 2019 - March 15, 2024 but for simpler calls you make the search smaller, in the simple code below its set to `last60min` to make it simple
# - `items=10`: number of news articles per page, maximum is 100
# - `page=1`: how many pages im getting, in this example to make it simple I am getting only 1 page

# %%
base_url = 'https://stocknewsapi.com/api/v1/category?section=alltickers'
url = f'{base_url}&sector=technology&exchange=NYSE,NASDAQ&index=SP500&country=USA&type=article&date=last60min&items=10&page=1&extra-fields=id&token={API_KEY}'
response = requests.get(url)
#print(response.text) ##uncomment this to check if you have output
#print(response.status_code) ## uncomment to check the status code (200 means successful)
news_data = response.json()
news_data
# Out:
# {'message': 'Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items.'}

# %% [markdown]
# ## Current code: Extracting News from API + Calculating Sentiment Scores
# `def fetch_news_for_sector(sector, page)`: this function is similar to the code above and uses the sector and number of pages you want to fetch as input. Reminder: 1 page has 100 news items maximum. The function returns the response in json format grabbing `data` (`response_news.json()['data']`) which contains all of the information
#
# `def calculate_sentiment_for_news`: using Vader I used the title/headline and summary text to calclate the sentiment scores, as defined in Vader documentation you get 4 values:
# - positive, neutral, and negative scores are ratios for proportions of text that fall in each category (so these should all add up to be 1... or close to it with float operation)
# - compound is the combined score from -1 to 1

# %%
#Calculate sentiment scores from the news urls extracted using API

#first step: function news for a sector 
def fetch_news_for_sector(sector, page):
    news_base_url = 'https://stocknewsapi.com/api/v1/category?section=alltickers'
    url_news = f'{news_base_url}&sector={sector}&exchange=NYSE,NASDAQ&index=SP500&country=USA&type=article&metadata=1&date={date_range}&items=100&page={page}&extra-fields=id&token={API_KEY}'
    response_news = requests.get(url_news)
    if response_news.status_code == 200:
        return response_news.json()['data']
    else: 
        print(f"Failed to fetch data for sector {sector} on page {page}, status code: {response_news.status_code}")
        print(f"Response content: {response_news.text}")
        return []
    
#second step: fetch the sentiment for the specific news 
def calculate_sentiment_for_news(title, text):
    analyzer = SentimentIntensityAnalyzer()
    title_text = title + " " + text
    return analyzer.polarity_scores(title_text)

# %% [markdown]
# This part creates a dictionary called `news_by_sector` which arranges the financial news data by sector, and saves all the important components of the news including the sentiment scores.

# %%
news_by_sector = {sector: {} for sector in sectors}
for sector in sectors:
    for page in range(1, 101):
        news_data = fetch_news_for_sector(sector, page)
        if not news_data:
            continue
        for news_item in news_data:
            news_title = news_item['title']
            news_text = news_item['text']
            sentiment_scores = calculate_sentiment_for_news(news_title, news_text)
            ticker = news_item['tickers'][0]
            if ticker not in news_by_sector[sector]:
                news_by_sector[sector][ticker] = []
            news_item['sentiment_neg'] = sentiment_scores['neg']
            news_item['sentiment_neu'] = sentiment_scores['neu']
            news_item['sentiment_pos'] = sentiment_scores['pos']
            news_item['sentiment_tot'] = sentiment_scores['compound']
            news_by_sector[sector][ticker].append(news_item)
# Out:
# Failed to fetch data for sector technology on page 1, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 2, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 3, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 4, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 5, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 6, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 7, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 8, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 9, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 10, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 11, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 12, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 13, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 14, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 15, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 16, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 17, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 18, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 19, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 20, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 21, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 22, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 23, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 24, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 25, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 26, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 27, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 28, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 29, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 30, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 31, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 32, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 33, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 34, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 35, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 36, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 37, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 38, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 39, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 40, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 41, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 42, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 43, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 44, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 45, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 46, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 47, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 48, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 49, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 50, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 51, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 52, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 53, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 54, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 55, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 56, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 57, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 58, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 59, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 60, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 61, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 62, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 63, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 64, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 65, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 66, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 67, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 68, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 69, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 70, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 71, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 72, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 73, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 74, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 75, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 76, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 77, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 78, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 79, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 80, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 81, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 82, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 83, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 84, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 85, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 86, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 87, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 88, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 89, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 90, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 91, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 92, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 93, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 94, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 95, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 96, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 97, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 98, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 99, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector technology on page 100, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 1, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 2, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 3, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 4, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 5, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 6, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 7, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 8, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 9, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 10, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 11, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 12, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 13, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 14, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 15, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 16, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 17, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 18, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 19, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 20, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 21, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 22, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 23, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 24, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 25, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 26, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 27, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 28, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 29, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 30, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 31, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 32, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 33, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 34, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 35, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 36, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 37, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 38, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 39, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 40, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 41, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 42, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 43, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 44, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 45, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 46, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 47, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 48, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 49, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 50, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 51, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 52, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 53, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 54, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 55, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 56, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 57, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 58, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 59, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 60, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 61, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 62, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 63, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 64, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 65, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 66, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 67, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 68, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 69, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 70, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 71, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 72, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 73, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 74, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 75, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 76, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 77, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 78, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 79, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 80, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 81, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 82, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 83, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 84, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 85, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 86, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 87, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 88, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 89, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 90, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 91, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 92, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 93, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 94, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 95, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 96, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 97, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 98, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 99, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector healthcare on page 100, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 1, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 2, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 3, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 4, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 5, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 6, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 7, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 8, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 9, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 10, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 11, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 12, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 13, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 14, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 15, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 16, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 17, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 18, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 19, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 20, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 21, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 22, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 23, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 24, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 25, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 26, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 27, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 28, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 29, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 30, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 31, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 32, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 33, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 34, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 35, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 36, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 37, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 38, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 39, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 40, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 41, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 42, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 43, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 44, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 45, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 46, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 47, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 48, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 49, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 50, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 51, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 52, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 53, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 54, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 55, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 56, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 57, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 58, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 59, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 60, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 61, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 62, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 63, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 64, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 65, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 66, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 67, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 68, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 69, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 70, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 71, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 72, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 73, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 74, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 75, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 76, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 77, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 78, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 79, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 80, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 81, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 82, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 83, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 84, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 85, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 86, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 87, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 88, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 89, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 90, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 91, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 92, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 93, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 94, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 95, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 96, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 97, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 98, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 99, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
# Failed to fetch data for sector financial on page 100, status code: 403
# Response content: {"message":"Trial Plans can query up to 3 news items. Activate your plan today and query up to 100 news items."}
